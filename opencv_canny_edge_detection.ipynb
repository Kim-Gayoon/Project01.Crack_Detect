# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
import numpy as np

def resize(img, size):
    return cv2.resize(img, size)

def grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

def gaussian_blur(img, kernel_size):
    return cv2.GaussianBlur(img,(kernel_size, kernel_size),0)

def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

def hist_norm(img):
    equ = cv2.equalizeHist(img)
    # res = np.hstack((img,equ)) #stacking images side-by-side
    return equ

temp_path ='/content/drive/MyDrive/Crack_Detector/before_canny_edege_images/crack1.jpg'
temp_img = cv2.imread(temp_path)
print(np.shape(temp_img))

# temp_img = grayscale(temp_img)
temp_img = hist_norm(grayscale(temp_img))

# temp_canny = canny(gaussian_blur(temp_img, 7), 100, 150)
temp_canny = canny(temp_img, 100, 200)
print(temp_canny)

plt.subplot(1, 2, 1)
plt.imshow(temp_img, cmap = 'gray')

plt.subplot(1, 2, 2)
plt.imshow(temp_canny, cmap = 'gray')
# Out:
# (298, 480, 3)
# [[  0   0 255 ...   0   0   0]
#  [  0   0 255 ...   0   0   0]
#  [  0 255   0 ...   0   0   0]
#  ...
#  [  0   0   0 ... 255   0   0]
#  [  0 255 255 ...   0 255   0]
#  [255   0 255 ...   0 255   0]]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline

def grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

def gaussian_blur(img, kernel_size):
    return cv2.GaussianBlur(img,(kernel_size, kernel_size),0)

def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

img = mpimg.imread('/content/drive/MyDrive/Crack_Detector/before_canny_edege_images/crack1.jpg')
plt.figure(figsize=(10,8))
print('This image is:', type(img), 'with dimensions:', img.shape)
plt.imshow(img)
plt.show()
# Out:
# This image is: <class 'numpy.ndarray'> with dimensions: (298, 480, 3)

# %%
def grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = grayscale(img)
plt.figure(figsize=(10,8))
plt.imshow(gray,cmap='gray')
plt.show()

# %%
def gaussian_blur(img, kernel_size):
    return cv2.GaussianBlur(img,(kernel_size, kernel_size),0)
kernel_size = 5
blur_gray = gaussian_blur(gray, kernel_size)

plt.figure(figsize=(10,8))
plt.imshow(blur_gray, cmap='gray')
plt.show()

# %%
def canny(img, low_threshold, high_threshold):
    """Applies the Canny transform"""
    return cv2.Canny(img, low_threshold, high_threshold)

low_threshold = 20
high_threshold = 170

edges = canny(blur_gray, low_threshold, high_threshold)

plt.figure(figsize=(10,8))
plt.imshow(edges, cmap='gray')
plt.show()
